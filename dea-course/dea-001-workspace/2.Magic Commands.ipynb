# %% [markdown]
# #Databricks Magic Commands
# - %pyhton, %sql, %scala, %r: Language Specific
# - %md: For markdown
# - %fs: Run file system command
# - %sh: Run shell script (driver node only)
# - %pip: Insall Python lib
# - %run: Include/Import another notebook in current notebook

# %% [markdown]
# ##%fs: Run file system command

# %%
# %fs
ls /

# %%
# %fs ls /databricks-datasets/

# %% [markdown]
# ##%sh: Run shell script (driver node only)

# %%
# %sh ps

# %% [markdown]
# ##%pip: Insall Python lib

# %%
import asyncio
display(asyncio)

# %%
# %pip install --upgrade pip

# %%
# %restart_python

# %%
# %sh python --version

# %%
# %pip list

# %%
# %pip install faker

# %%
# %restart_python

# %%
# %run "./2.1 Environment Variables"

# %%
env

# %%
print_env_info()
