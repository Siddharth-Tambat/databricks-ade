# %%
display(dbutils.fs.ls('/'))

# %%
items = dbutils.fs.ls('/databricks-datasets/')

# %%
folder = [i for i in items if i.path.endswith('/')]
display(folder)
files = [i for i in items if not i.path.endswith('/')]
display(files)

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
db = dbutils

# %%
db.fs.help('cp')
