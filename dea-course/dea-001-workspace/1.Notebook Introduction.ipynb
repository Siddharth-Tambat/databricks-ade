# %% [markdown]
# #Notebook introduction for databricks notebook
# ## H2
# - bullet 1

# %%
print('hello')
print('bye')

# %%
# %sql
SELECT 'Hello from SQL'

# %%
 print("Let's Go!!!")

# %%
# %fs
ls

# %%
# %pip list

# %%
# %sh ls
