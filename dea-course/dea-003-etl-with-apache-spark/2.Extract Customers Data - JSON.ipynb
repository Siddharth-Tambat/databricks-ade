-- %% [markdown]
-- #Extract Data from the Customer JSON files

-- %%
%fs ls /Volumes/gizmobox_ct/landing/operational_data/customers/

-- %%
SELECT * FROM json.`dbfs:/Volumes/gizmobox_ct/landing/operational_data/customers/customers_2024_10.json`

-- %%
SELECT * FROM json.`dbfs:/Volumes/gizmobox_ct/landing/operational_data/customers/customers_2024_*.json`

-- %%
SELECT * FROM json.`dbfs:/Volumes/gizmobox_ct/landing/operational_data/customers/*.json`

-- %%
SELECT *, _metadata FROM json.`dbfs:/Volumes/gizmobox_ct/landing/operational_data/customers/*.json`

-- %%
CREATE OR REPLACE VIEW gizmobox_ct.bronze.v_customers AS
  SELECT 
    *, _metadata 
  FROM json.`dbfs:/Volumes/gizmobox_ct/landing/operational_data/customers/*.json`

-- %%
SELECT * FROM gizmobox_ct.bronze.v_customers
