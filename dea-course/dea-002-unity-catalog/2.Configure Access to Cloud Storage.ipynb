# %% [markdown]
# #Configure Access to Cloud Storage via Unity Catalog

# %% [markdown]
# ###Access Cloud Storage

# %%
# %fs ls 'abfss://termi-001@databrickstermiextdl.dfs.core.windows.net/'

# %% [markdown]
# ###Create External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS termi_001_ext
  URL 'abfss://termi-001@databrickstermiextdl.dfs.core.windows.net/'
  WITH (STORAGE CREDENTIAL dea_termi_ext_sc)
  COMMENT 'External Location for Termi-001'
